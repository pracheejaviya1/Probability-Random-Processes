# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math

# %% [markdown]
# ## Gaussian distribution
# ---

# %% [markdown]
# ## PDF :

# %%
mu = 0
variance = 1
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.show()

# %% [markdown]
# ## CDF :

# %%
mu = 0
variance = 1
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, stats.norm.cdf(x, mu, sigma))
plt.show()

# %% [markdown]
# Q1) M=0 :

# %%
mu = 1
variance = 1
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.show()

# %%
x=np.linspace(-20,20,100)
y= 1/(1+np.exp((2*x+1)/2))
plt.plot(x,y,1)
plt.show()

# %%
x=np.linspace(-20,20,100)
y= 1/(1+np.exp((2*x+1)/10))
plt.plot(x,y,1)
plt.show()

# %%
x=np.linspace(-20,20,100)
y= 1/(1+np.exp((2*x-1)/10))
z= 1/(1+np.exp((2*x-1)/2))
a=0.9
plt.plot(x,y,'r')
plt.plot(x,z,'b')
plt.show()

# %%
x=np.linspace(-20,20,100)
y= 1/(1+np.exp((-2*x+1)/10))
z= 1/(1+np.exp((-2*x+1)/2))
plt.plot(x,y,'m')
plt.plot(x,z,'y')
plt.show()

# %%
z= 1/(1+np.exp((2*x-1)/2))
w= 1/(1+np.exp((-2*x+1)/2))
plt.plot(x,(z+w),'c')
